# %%
# !git clone https://github.com/jassi-jassi/SmartAlpha-ET-Hackathon-Submission.git
# %cd SmartAlpha-ET-Hackathon-Submission
# Out:
# Cloning into 'SmartAlpha-ET-Hackathon-Submission'...
# remote: Enumerating objects: 175, done.
# remote: Counting objects: 100% (175/175), done.
# remote: Compressing objects: 100% (164/164), done.
# remote: Total 175 (delta 76), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (175/175), 86.34 KiB | 4.80 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# /content/SmartAlpha-ET-Hackathon-Submission

# %%
# !pip install -r requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 54.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 5.7 MB/s eta 0:00:00

# %%
import os

os.environ["AWS_ACCESS_KEY_ID"] = "YOUR_AWS_ACCESS_KEY"
os.environ["AWS_SECRET_ACCESS_KEY"] = "YOUR_AWS_SECRET_KEY"
os.environ["AWS_DEFAULT_REGION"] = "YOUR REGION"

# %%
import sys
sys.path.append('/content/SmartAlpha-ET-Hackathon-Submission/SmartAlpha')

from SmartAlpha.main import SmartAlpha

# %%
from main import SmartAlpha
agent = SmartAlpha()
agent.run_all()
# Out:
# ╔══════════════════════════════════════════════════════╗
# ║         SmartAlpha AI - ET Hackathon 2026            ║
# ║         Track 6: AI for the Indian Investor          ║
# ╚══════════════════════════════════════════════════════╝
#
#   AWS region : us-east-1
#   Profile    : default
#
#
# ───────────────────────────────────────────────────────
#
# [Scenario 1] Bulk Deal Filing Analysis...
#   [1/4] DataAgent: fetching filing...
#   [2/4] SignalAgent: classifying deal...
#   [3/4] ContextAgent: enriching with fundamentals...
#   [4/4] AlertAgent: generating retail alert...
#   Done: CRITICAL ALERT - ABC FMCG Ltd Promoter Sells Stake at Discount
#   Output saved: outputs/bulk_deal_20260329_105243.json
#
# ───────────────────────────────────────────────────────
#
# [Scenario 2] Technical Breakout + Conflicting Signals...
#   [1/4] DataAgent: fetching technical data...
#   [2/4] PatternAgent: detecting pattern...
#   [3/4] ConflictAgent: resolving conflicting signals...
# ...

# %%
import shutil
import os

# Create outputs folder inside SmartAlpha (if not exists)
os.makedirs("SmartAlpha-ET-Hackathon-Submission/SmartAlpha/outputs", exist_ok=True)

# Copy your outputs
shutil.copytree("outputs", "SmartAlpha-ET-Hackathon-Submission/SmartAlpha/outputs", dirs_exist_ok=True)
# Out:
# 'SmartAlpha-ET-Hackathon-Submission/SmartAlpha/outputs'

# %%
# !git config --global user.email "jashanpreetsinghwazir@gmail.com"
# !git config --global user.name "Jashanpreet Singh"

# %%
# %cd /content/SmartAlpha-ET-Hackathon-Submission

# !git add .
# !git commit -m "Added outputs for evaluation"
# !git push
# Out:
# /content/SmartAlpha-ET-Hackathon-Submission
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address

# %%
# !git push https://jassi-jassi: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@github.com/jassi-jassi/SmartAlpha-ET-Hackathon-Submission.git
# Out:
# Enumerating objects: 32, done.
# Counting objects: 100% (32/32), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (24/24), done.
# Writing objects: 100% (27/27), 42.06 KiB | 5.26 MiB/s, done.
# Total 27 (delta 4), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (4/4), completed with 2 local objects.
# To https://github.com/jassi-jassi/SmartAlpha-ET-Hackathon-Submission.git
#    e69cce3..a31b631  main -> main
